# %% [markdown]
# ## Grids
# = allgemeine Typen von Plots, die es ermögl. mehrerer Diagramme entlang von Zeilen und Spalten darzustellen

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
tips = pd.read_csv('../Daten/csv/tips.csv')
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %% [markdown]
# ### Pairgrid

# %%
grid = sns.PairGrid(tips)
grid.map(plt.scatter)

# %%
grid = sns.PairGrid(tips)
#Platzierung der Plots ändern
grid.map_diag(plt.hist) #auf der Diagonalen sind Histogramme
grid.map_upper(plt.scatter) #alle Dia über der Diagonalen
grid.map_lower(sns.kdeplot) #alle Dia unter der Diagonalen
# Out:
# C:\Users\flfr\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\contour.py:967: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)

# %% [markdown]
# ### Pairplot
# = einfachere Version des PairGrid

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue='smoker')

# %% [markdown]
# ### FacetGrid
# = allgemeine Weg um eine Vielzahl an Diagrammen in einem Grid zu erstellen

# %%
grid = sns.FacetGrid(tips, col="time", row="smoker", hue="sex")
#grid.map(plt.hist, 'total_bill') #hist benötigt 1 Argument
grid.map(plt.scatter, 'total_bill', 'tip').add_legend() #scatter benötigt 2 Argumente

# %% [markdown]
# ### JointGrid
# JointGrid ist die allg. Version für jointplot()

# %%
grid = sns.JointGrid(x="total_bill", y="tip", data=tips)
grid.plot(sns.regplot, sns.distplot) #in einem Grid werden 2 verschiedene Dia. / Plots dargestellt
